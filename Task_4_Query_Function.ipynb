# %% [markdown]
# # Daily Task - 4
# ## Explore Query Function 2 examples.
# # ---------------------------------------------------------------------------------------------------------------

# %%
import pandas as pd

# %%
drink = pd.read_csv('drinks.csv')
drink.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drink.query('country == "Algeria"')
# Out:
#    country  beer_servings  spirit_servings  wine_servings  \
# 2  Algeria             25                0             14
#
#    total_litres_of_pure_alcohol continent
# 2                           0.7        AF

# %%
drink.query('spirit_servings == 1')
# Out:
#            country  beer_servings  spirit_servings  wine_servings  \
# 28   Cote d'Ivoire             37                1              7
# 31        Cameroon            147                1              4
# 34            Chad             15                1              1
# 39           Congo             76                1              9
# 78       Indonesia              5                1              0
# 104           Mali              5                1              1
# 116        Myanmar              5                1              0
# 150        Senegal              9                1              7
# 171    Timor-Leste              1                1              4
#
#      total_litres_of_pure_alcohol continent
# 28                            4.0        AF
# 31                            5.8        AF
# 34                            0.4        AF
# 39                            1.7        AF
# 78                            0.1        AS
# ...

# %%
drink.query('country == "Andorra" and continent == "EU"')
# Out:
#    country  beer_servings  spirit_servings  wine_servings  \
# 3  Andorra            245              138            312
#
#    total_litres_of_pure_alcohol continent
# 3                          12.4        EU

# %%
drink.query('beer_servings > 340')
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 45   Czech Republic            361              170            134
# 62            Gabon            347               98             59
# 65          Germany            346              117            175
# 98        Lithuania            343              244             56
# 117         Namibia            376                3              1
# 135          Poland            343              215             56
#
#      total_litres_of_pure_alcohol continent
# 45                           11.8        EU
# 62                            8.9        AF
# 65                           11.3        EU
# 98                           12.9        EU
# 117                           6.8        AF
# 135                          10.9        EU

# %%
drink.query('country.str.contains("Germany")')
# Out:
#     country  beer_servings  spirit_servings  wine_servings  \
# 65  Germany            346              117            175
#
#     total_litres_of_pure_alcohol continent
# 65                          11.3        EU

# %%
count = 2
drink.query('wine_servings == @count')
# Out:
#           country  beer_servings  spirit_servings  wine_servings  \
# 54    El Salvador             52               69              2
# 69      Guatemala             53               69              2
# 70         Guinea              9                0              2
# 74       Honduras             69               98              2
# 88          Kenya             58               22              2
# 96        Liberia             19              152              2
# 124       Nigeria             42                5              2
# 153  Sierra Leone             25                3              2
# 164     Swaziland             90                2              2
#
#      total_litres_of_pure_alcohol continent
# 54                            2.2       NaN
# 69                            2.2       NaN
# 70                            0.2        AF
# 74                            3.0       NaN
# 88                            1.8        AF
# 96                            3.1        AF
# ...

# %% [markdown]
# # The End!!!
